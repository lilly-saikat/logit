# %%
# %matplotlib inline

# %%
import os
import re
import pandas as po
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import fancyimpute
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, roc_curve, auc

# %%
path = os.getcwd()
path = re.sub('notebooks', '', path)

# %%
input_raw = po.read_csv(path+'data/raw/train.csv', header=0)

# %%
input_raw.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
input_raw.shape
# Out:
# (891, 12)

# %%
input_raw['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# # Simulating Random Data

# %% [markdown]
# test = np.random.normal(loc=0, scale=1, size=10000)
#
# test = test.reshape(1000,10)
#
# test = po.DataFrame(test, columns=['var_'+str(i) for i in range(10)])
#
# for col in test.columns:
#
#     test[col] = (test[col]*np.random.randint(low=10, high=100, size=1))
#
# test.describe()
#
# test.mean()
#
# test.cov()
#
# test1 = po.DataFrame(np.random.multivariate_normal(test.mean(), test.cov(), size=10000), columns=test.columns)
#
# for col in test.columns:
#
#     test1[col] = test1[col].clip(test[col].min(), test[col].max())
#
# test1 = test1.fillna(test1.mean())
#
# test1.info()
#
# sns.distplot(test['var_0'])
#
# sns.distplot(test1['var_0'])

# %%
input_raw = input_raw.set_index('PassengerId')

# %%
input_raw.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
input_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
print(input_raw.groupby('Survived')['Age'].mean())
print(input_raw.groupby('Survived')['Age'].std())
# Out:
# Survived
# 0    30.626179
# 1    28.343690
# Name: Age, dtype: float64
# Survived
# 0    14.172110
# 1    14.950952
# Name: Age, dtype: float64

# %%
fig=plt.figure(figsize=[20,10])
input_raw1 = input_raw.copy()
#input_raw1 = input_raw1.fillna(input_raw1.mean())
input_raw1 = input_raw1.dropna(axis=0)
sns.distplot(input_raw1.loc[input_raw1['Survived']==0, 'Age'], label='Dieded')
sns.distplot(input_raw1.loc[input_raw1['Survived']==1, 'Age'], label='Alive')
plt.legend(fontsize=16)

# %%
input_raw2 = input_raw.copy()
input_raw2['Age'] = po.to_numeric(input_raw2['Age'], errors='coerce')
no_na = input_raw.dropna(axis=0).reset_index()
for i in input_raw2.index:
    print(input_raw2.loc[i, 'Age'])
    #if input_raw2.loc[i, 'Age'] == input_raw2.loc[6, 'Age']:
    if np.isnan(input_raw2.loc[i, 'Age']):
        using = no_na.ix[np.random.randint(low=0, high=no_na.index.max(), size=1),'Age']
        print("Using :%f" % using)
        input_raw2['Age'].loc[i,] = using
    #else:
        #print(input_raw2.loc[i, 'Age'])
# Out:
# 22.0
# 38.0
# 26.0
# 35.0
# 35.0
# nan
# Using :31.000000
# 54.0
# 2.0
# 27.0
# 14.0
# C:\Continuum\lib\site-packages\ipykernel\__main__.py:8: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
# C:\Continuum\lib\site-packages\pandas\core\indexing.py:601: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# 4.0
# 58.0
# 20.0
# 39.0
# 14.0
# 55.0
# 2.0
# nan
# Using :24.000000
# 31.0
# nan
# Using :40.000000
# 35.0
# 34.0
# 15.0
# 28.0
# 8.0
# 38.0
# nan
# Using :17.000000
# 19.0
# nan
# Using :27.000000
# nan
# Using :29.000000
# 40.0
# nan
# Using :54.000000
# nan
# Using :24.000000
# 66.0
# 28.0
# 42.0
# nan
# Using :27.000000
# 21.0
# 18.0
# 14.0
# 40.0
# 27.0
# nan
# Using :52.000000
# 3.0
# 19.0
# nan
# Using :4.000000
# nan
# Using :33.000000
# nan
# Using :40.000000
# nan
# Using :18.000000
# 18.0
# 7.0
# 21.0
# 49.0
# 29.0
# 65.0
# nan
# Using :22.000000
# 21.0
# 28.5
# 5.0
# 11.0
# 22.0
# 38.0
# 45.0
# 4.0
# nan
# Using :44.000000
# nan
# Using :30.000000
# 29.0
# 19.0
# 17.0
# 26.0
# 32.0
# 16.0
# 21.0
# 26.0
# 32.0
# 25.0
# nan
# Using :36.000000
# nan
# Using :27.000000
# 0.83
# 30.0
# 22.0
# 29.0
# nan
# Using :36.500000
# 28.0
# 17.0
# 33.0
# 16.0
# nan
# Using :30.000000
# 23.0
# 24.0
# 29.0
# 20.0
# 46.0
# 26.0
# 59.0
# nan
# Using :52.000000
# 71.0
# 23.0
# 34.0
# 34.0
# 28.0
# nan
# Using :38.000000
# 21.0
# 33.0
# 37.0
# 28.0
# 21.0
# nan
# Using :44.000000
# 38.0
# nan
# Using :61.000000
# 47.0
# 14.5
# 22.0
# 20.0
# 17.0
# 21.0
# 70.5
# 29.0
# 24.0
# 2.0
# 21.0
# nan
# Using :30.000000
# 32.5
# 32.5
# 54.0
# 12.0
# nan
# Using :24.000000
# 24.0
# nan
# Using :45.000000
# 45.0
# 33.0
# 20.0
# 47.0
# 29.0
# 25.0
# 23.0
# 19.0
# 37.0
# 16.0
# 24.0
# nan
# Using :36.000000
# 22.0
# 24.0
# 19.0
# 18.0
# 19.0
# 27.0
# 9.0
# 36.5
# 42.0
# 51.0
# 22.0
# 55.5
# 40.5
# nan
# Using :27.000000
# 51.0
# 16.0
# 30.0
# nan
# Using :39.000000
# nan
# Using :19.000000
# 44.0
# 40.0
# 26.0
# 17.0
# 1.0
# 9.0
# nan
# Using :23.000000
# 45.0
# nan
# Using :27.000000
# 28.0
# 61.0
# 4.0
# 1.0
# 21.0
# 56.0
# 18.0
# nan
# Using :45.000000
# 50.0
# 30.0
# 36.0
# nan
# Using :54.000000
# nan
# Using :37.000000
# 9.0
# 1.0
# 4.0
# nan
# Using :45.000000
# nan
# Using :31.000000
# 45.0
# 40.0
# 36.0
# 32.0
# 19.0
# 19.0
# 3.0
# 44.0
# 58.0
# nan
# Using :25.000000
# 42.0
# nan
# Using :23.000000
# 24.0
# 28.0
# nan
# Using :36.000000
# 34.0
# 45.5
# 18.0
# 2.0
# 32.0
# 26.0
# 16.0
# 40.0
# 24.0
# 35.0
# 22.0
# 30.0
# nan
# Using :56.000000
# 31.0
# 27.0
# 42.0
# 32.0
# 30.0
# 16.0
# 27.0
# 51.0
# nan
# Using :11.000000
# 38.0
# 22.0
# 19.0
# 20.5
# 18.0
# nan
# Using :19.000000
# 35.0
# 29.0
# 59.0
# 5.0
# 24.0
# nan
# Using :19.000000
# 44.0
# 8.0
# 19.0
# 33.0
# nan
# Using :19.000000
# nan
# Using :25.000000
# 29.0
# 22.0
# 30.0
# 44.0
# 25.0
# 24.0
# 37.0
# 54.0
# nan
# Using :30.000000
# 29.0
# 62.0
# 30.0
# 41.0
# 29.0
# nan
# Using :80.000000
# 30.0
# 35.0
# 50.0
# nan
# Using :47.000000
# 3.0
# 52.0
# 40.0
# nan
# Using :49.000000
# 36.0
# 16.0
# 25.0
# 58.0
# 35.0
# nan
# Using :58.000000
# 25.0
# 41.0
# 37.0
# nan
# Using :56.000000
# 63.0
# 45.0
# nan
# Using :31.000000
# 7.0
# 35.0
# 65.0
# 28.0
# 16.0
# 19.0
# nan
# Using :1.000000
# 33.0
# 30.0
# 22.0
# 42.0
# 22.0
# 26.0
# 19.0
# 36.0
# 24.0
# 24.0
# nan
# Using :36.000000
# 23.5
# 2.0
# nan
# Using :42.000000
# 50.0
# nan
# Using :38.000000
# nan
# Using :17.000000
# 19.0
# nan
# Using :36.000000
# nan
# Using :29.000000
# 0.92
# nan
# Using :48.000000
# 17.0
# 30.0
# 30.0
# 24.0
# 18.0
# 26.0
# 28.0
# 43.0
# 26.0
# 24.0
# 54.0
# 31.0
# 40.0
# 22.0
# 27.0
# 30.0
# 22.0
# nan
# Using :42.000000
# 36.0
# 61.0
# 36.0
# 31.0
# 16.0
# nan
# Using :38.000000
# 45.5
# 38.0
# 16.0
# nan
# Using :54.000000
# nan
# Using :23.000000
# 29.0
# 41.0
# 45.0
# 45.0
# 2.0
# 24.0
# 28.0
# 25.0
# 36.0
# 24.0
# 40.0
# nan
# Using :2.000000
# 3.0
# 42.0
# 23.0
# nan
# Using :48.000000
# 15.0
# 25.0
# nan
# Using :18.000000
# 28.0
# 22.0
# 38.0
# nan
# Using :32.000000
# nan
# Using :24.000000
# 40.0
# 29.0
# 45.0
# 35.0
# nan
# Using :54.000000
# 30.0
# 60.0
# nan
# Using :44.000000
# nan
# Using :61.000000
# 24.0
# 25.0
# 18.0
# 19.0
# 22.0
# 3.0
# nan
# Using :17.000000
# 22.0
# 27.0
# 20.0
# 19.0
# 42.0
# 1.0
# 32.0
# 35.0
# nan
# Using :16.000000
# 18.0
# 1.0
# 36.0
# nan
# Using :19.000000
# 17.0
# 36.0
# 21.0
# 28.0
# 23.0
# 24.0
# 22.0
# 31.0
# 46.0
# 23.0
# 28.0
# 39.0
# 26.0
# 21.0
# 28.0
# 20.0
# 34.0
# 51.0
# 3.0
# 21.0
# nan
# Using :45.000000
# nan
# Using :42.000000
# nan
# Using :25.000000
# 33.0
# nan
# Using :39.000000
# 44.0
# nan
# Using :49.000000
# 34.0
# 18.0
# 30.0
# 10.0
# nan
# Using :18.000000
# 21.0
# 29.0
# 28.0
# 18.0
# nan
# Using :54.000000
# 28.0
# 19.0
# nan
# Using :15.000000
# 32.0
# 28.0
# nan
# Using :65.000000
# 42.0
# 17.0
# 50.0
# 14.0
# 21.0
# 24.0
# 64.0
# 31.0
# 45.0
# 20.0
# 25.0
# 28.0
# nan
# Using :23.000000
# 4.0
# 13.0
# 34.0
# 5.0
# 52.0
# 36.0
# nan
# Using :47.000000
# 30.0
# 49.0
# nan
# Using :2.000000
# 29.0
# 65.0
# nan
# Using :37.000000
# 50.0
# nan
# Using :38.000000
# 48.0
# 34.0
# 47.0
# 48.0
# nan
# Using :14.000000
# 38.0
# nan
# Using :2.000000
# 56.0
# nan
# Using :38.000000
# 0.75
# nan
# Using :16.000000
# 38.0
# 33.0
# 23.0
# 22.0
# nan
# Using :31.000000
# 34.0
# 29.0
# 22.0
# 2.0
# 9.0
# nan
# Using :50.000000
# 50.0
# 63.0
# 25.0
# nan
# Using :33.000000
# 35.0
# 58.0
# 30.0
# 9.0
# nan
# Using :0.920000
# 21.0
# 55.0
# 71.0
# 21.0
# nan
# Using :32.500000
# 54.0
# nan
# Using :58.000000
# 25.0
# 24.0
# 17.0
# 21.0
# nan
# Using :52.000000
# 37.0
# 16.0
# 18.0
# 33.0
# nan
# Using :24.000000
# 28.0
# 26.0
# 29.0
# nan
# Using :36.000000
# 36.0
# 54.0
# 24.0
# 47.0
# 34.0
# nan
# Using :54.000000
# 36.0
# 32.0
# 30.0
# 22.0
# nan
# Using :52.000000
# 44.0
# nan
# Using :36.000000
# 40.5
# 50.0
# nan
# Using :18.000000
# 39.0
# 23.0
# 2.0
# nan
# Using :19.000000
# 17.0
# nan
# Using :44.000000
# 30.0
# 7.0
# 45.0
# 30.0
# nan
# Using :40.000000
# 22.0
# 36.0
# 9.0
# 11.0
# 32.0
# 50.0
# 64.0
# 19.0
# nan
# Using :24.000000
# 33.0
# 8.0
# 17.0
# 27.0
# nan
# Using :49.000000
# 22.0
# 22.0
# 62.0
# 48.0
# nan
# Using :18.000000
# 39.0
# 36.0
# nan
# Using :32.000000
# 40.0
# 28.0
# nan
# Using :36.000000
# nan
# Using :50.000000
# 24.0
# 19.0
# 29.0
# nan
# Using :31.000000
# 32.0
# 62.0
# 53.0
# 36.0
# nan
# Using :52.000000
# 16.0
# 19.0
# 34.0
# 39.0
# nan
# Using :52.000000
# 32.0
# 25.0
# 39.0
# 54.0
# 36.0
# nan
# Using :47.000000
# 18.0
# 47.0
# 60.0
# 22.0
# nan
# Using :4.000000
# 35.0
# 52.0
# 47.0
# nan
# Using :33.000000
# 37.0
# 36.0
# nan
# Using :35.000000
# 49.0
# nan
# Using :35.000000
# 49.0
# 24.0
# nan
# Using :36.000000
# nan
# Using :51.000000
# 44.0
# 35.0
# 36.0
# 30.0
# 27.0
# 22.0
# 40.0
# 39.0
# nan
# Using :44.000000
# nan
# Using :40.000000
# nan
# Using :58.000000
# 35.0
# 24.0
# 34.0
# 26.0
# 4.0
# 26.0
# 27.0
# 42.0
# 20.0
# 21.0
# 21.0
# 61.0
# 57.0
# 21.0
# 26.0
# nan
# Using :39.000000
# 80.0
# 51.0
# 32.0
# nan
# Using :47.000000
# 9.0
# 28.0
# 32.0
# 31.0
# 41.0
# nan
# Using :56.000000
# 20.0
# 24.0
# 2.0
# nan
# Using :2.000000
# 0.75
# 48.0
# 19.0
# 56.0
# nan
# Using :38.000000
# 23.0
# nan
# Using :48.000000
# 18.0
# 21.0
# nan
# Using :35.000000
# 18.0
# 24.0
# nan
# Using :52.000000
# 32.0
# 23.0
# 58.0
# 50.0
# 40.0
# 47.0
# 36.0
# 20.0
# 32.0
# 25.0
# nan
# Using :23.000000
# 43.0
# nan
# Using :35.000000
# 40.0
# 31.0
# 70.0
# 31.0
# nan
# Using :4.000000
# 18.0
# 24.5
# 18.0
# 43.0
# 36.0
# nan
# Using :27.000000
# 27.0
# 20.0
# 14.0
# 60.0
# 25.0
# 14.0
# 19.0
# 18.0
# 15.0
# 31.0
# 4.0
# nan
# Using :42.000000
# 25.0
# 60.0
# 52.0
# 44.0
# nan
# Using :33.000000
# 49.0
# 42.0
# 18.0
# 35.0
# 18.0
# 25.0
# 26.0
# 39.0
# 45.0
# 42.0
# 22.0
# nan
# Using :27.000000
# 24.0
# nan
# Using :19.000000
# 48.0
# 29.0
# 52.0
# 19.0
# 38.0
# 27.0
# nan
# Using :62.000000
# 33.0
# 6.0
# 17.0
# 34.0
# 50.0
# 27.0
# 20.0
# 30.0
# nan
# Using :65.000000
# 25.0
# 25.0
# 29.0
# 11.0
# nan
# Using :30.000000
# 23.0
# 23.0
# 28.5
# 48.0
# 35.0
# nan
# Using :38.000000
# nan
# Using :21.000000
# nan
# Using :41.000000
# 36.0
# 21.0
# 24.0
# 31.0
# 70.0
# 16.0
# 30.0
# 19.0
# 31.0
# 4.0
# 6.0
# 33.0
# 23.0
# 48.0
# 0.67
# 28.0
# 18.0
# 34.0
# 33.0
# nan
# Using :25.000000
# 41.0
# 20.0
# 36.0
# 16.0
# 51.0
# nan
# Using :21.000000
# 30.5
# nan
# Using :27.000000
# 32.0
# 24.0
# 48.0
# 57.0
# nan
# Using :22.000000
# 54.0
# 18.0
# nan
# Using :52.000000
# 5.0
# nan
# Using :29.000000
# 43.0
# 13.0
# 17.0
# 29.0
# nan
# Using :60.000000
# 25.0
# 25.0
# 18.0
# 8.0
# 1.0
# 46.0
# nan
# Using :53.000000
# 16.0
# nan
# Using :58.000000
# nan
# Using :3.000000
# 25.0
# 39.0
# 49.0
# 31.0
# 30.0
# 30.0
# 34.0
# 31.0
# 11.0
# 0.42
# 27.0
# 31.0
# 39.0
# 18.0
# 39.0
# 33.0
# 26.0
# 39.0
# 35.0
# 6.0
# 30.5
# nan
# Using :33.000000
# 23.0
# 31.0
# 43.0
# 10.0
# 52.0
# 27.0
# 38.0
# 27.0
# 2.0
# nan
# Using :60.000000
# nan
# Using :38.000000
# 1.0
# nan
# Using :31.000000
# 62.0
# 15.0
# 0.83
# nan
# Using :31.000000
# 23.0
# 18.0
# 39.0
# 21.0
# nan
# Using :24.000000
# 32.0
# nan
# Using :40.000000
# 20.0
# 16.0
# 30.0
# 34.5
# 17.0
# 42.0
# nan
# Using :18.000000
# 35.0
# 28.0
# nan
# Using :52.000000
# 4.0
# 74.0
# 9.0
# 16.0
# 44.0
# 18.0
# 45.0
# 51.0
# 24.0
# nan
# Using :31.000000
# 41.0
# 21.0
# 48.0
# nan
# Using :31.000000
# 24.0
# 42.0
# 27.0
# 31.0
# nan
# Using :33.000000
# 4.0
# 26.0
# 47.0
# 33.0
# 47.0
# 28.0
# 15.0
# 20.0
# 19.0
# nan
# Using :1.000000
# 56.0
# 25.0
# 33.0
# 22.0
# 28.0
# 25.0
# 39.0
# 27.0
# 19.0
# nan
# Using :35.000000
# 26.0
# 32.0

# %%
plt.figure(figsize=[20,10])
sns.distplot(input_raw['Age'].dropna(axis=0), label='Original', kde=0)
sns.distplot(input_raw2['Age'], label='Imputed', kde=0)
plt.legend(fontsize=16)

# %% [markdown]
# MICE = Multiple Imputation by Chained Equations

# %%
input_raw3 = input_raw.copy()
for col in input_raw3.columns:
    if input_raw3[col].dtype=='object':
        del input_raw3[col]
input_raw4 = po.concat([input_raw3.drop('Pclass', axis=1), po.get_dummies(input_raw3['Pclass'], prefix="Pclass_")], axis=0)

# %%
input_raw4.dtypes
# Out:
# Age          float64
# Fare         float64
# Parch        float64
# Pclass__1    float64
# Pclass__2    float64
# Pclass__3    float64
# SibSp        float64
# Survived     float64
# dtype: object

# %%
input_raw4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1782 entries, 1 to 891
# Data columns (total 8 columns):
# Age          714 non-null float64
# Fare         891 non-null float64
# Parch        891 non-null float64
# Pclass__1    891 non-null float64
# Pclass__2    891 non-null float64
# Pclass__3    891 non-null float64
# SibSp        891 non-null float64
# Survived     891 non-null float64
# dtypes: float64(8)
# memory usage: 125.3 KB

# %%
exog = input_raw3['Survived']
endog = input_raw3.drop('Survived', axis=1)

# %%
endog1 = po.DataFrame(fancyimpute.MICE().complete(endog.values), columns=endog.columns)
# Out:
# [MICE] Completing matrix with shape (891, 5)
# [MICE] Starting imputation round 1/110, elapsed time 0.000
# [MICE] Starting imputation round 2/110, elapsed time 0.000
# [MICE] Starting imputation round 3/110, elapsed time 0.000
# [MICE] Starting imputation round 4/110, elapsed time 0.004
# [MICE] Starting imputation round 5/110, elapsed time 0.004
# [MICE] Starting imputation round 6/110, elapsed time 0.004
# [MICE] Starting imputation round 7/110, elapsed time 0.004
# [MICE] Starting imputation round 8/110, elapsed time 0.004
# [MICE] Starting imputation round 9/110, elapsed time 0.008
# [MICE] Starting imputation round 10/110, elapsed time 0.008
# [MICE] Starting imputation round 11/110, elapsed time 0.008
# [MICE] Starting imputation round 12/110, elapsed time 0.008
# [MICE] Starting imputation round 13/110, elapsed time 0.008
# [MICE] Starting imputation round 14/110, elapsed time 0.012
# [MICE] Starting imputation round 15/110, elapsed time 0.012
# [MICE] Starting imputation round 16/110, elapsed time 0.012
# [MICE] Starting imputation round 17/110, elapsed time 0.012
# [MICE] Starting imputation round 18/110, elapsed time 0.012
# [MICE] Starting imputation round 19/110, elapsed time 0.016
# [MICE] Starting imputation round 20/110, elapsed time 0.016
# [MICE] Starting imputation round 21/110, elapsed time 0.016
# [MICE] Starting imputation round 22/110, elapsed time 0.016
# [MICE] Starting imputation round 23/110, elapsed time 0.016
# [MICE] Starting imputation round 24/110, elapsed time 0.016
# [MICE] Starting imputation round 25/110, elapsed time 0.016
# [MICE] Starting imputation round 26/110, elapsed time 0.020
# [MICE] Starting imputation round 27/110, elapsed time 0.020
# [MICE] Starting imputation round 28/110, elapsed time 0.020
# [MICE] Starting imputation round 29/110, elapsed time 0.020
# [MICE] Starting imputation round 30/110, elapsed time 0.020
# [MICE] Starting imputation round 31/110, elapsed time 0.024
# [MICE] Starting imputation round 32/110, elapsed time 0.024
# [MICE] Starting imputation round 33/110, elapsed time 0.024
# [MICE] Starting imputation round 34/110, elapsed time 0.024
# [MICE] Starting imputation round 35/110, elapsed time 0.024
# [MICE] Starting imputation round 36/110, elapsed time 0.028
# [MICE] Starting imputation round 37/110, elapsed time 0.028
# [MICE] Starting imputation round 38/110, elapsed time 0.028
# [MICE] Starting imputation round 39/110, elapsed time 0.028
# [MICE] Starting imputation round 40/110, elapsed time 0.032
# [MICE] Starting imputation round 41/110, elapsed time 0.032
# [MICE] Starting imputation round 42/110, elapsed time 0.032
# [MICE] Starting imputation round 43/110, elapsed time 0.032
# [MICE] Starting imputation round 44/110, elapsed time 0.036
# [MICE] Starting imputation round 45/110, elapsed time 0.036
# [MICE] Starting imputation round 46/110, elapsed time 0.036
# [MICE] Starting imputation round 47/110, elapsed time 0.040
# [MICE] Starting imputation round 48/110, elapsed time 0.040
# [MICE] Starting imputation round 49/110, elapsed time 0.040
# [MICE] Starting imputation round 50/110, elapsed time 0.040
# [MICE] Starting imputation round 51/110, elapsed time 0.040
# [MICE] Starting imputation round 52/110, elapsed time 0.044
# [MICE] Starting imputation round 53/110, elapsed time 0.044
# [MICE] Starting imputation round 54/110, elapsed time 0.044
# [MICE] Starting imputation round 55/110, elapsed time 0.044
# [MICE] Starting imputation round 56/110, elapsed time 0.044
# [MICE] Starting imputation round 57/110, elapsed time 0.044
# [MICE] Starting imputation round 58/110, elapsed time 0.048
# [MICE] Starting imputation round 59/110, elapsed time 0.048
# [MICE] Starting imputation round 60/110, elapsed time 0.048
# [MICE] Starting imputation round 61/110, elapsed time 0.048
# [MICE] Starting imputation round 62/110, elapsed time 0.048
# [MICE] Starting imputation round 63/110, elapsed time 0.052
# [MICE] Starting imputation round 64/110, elapsed time 0.052
# [MICE] Starting imputation round 65/110, elapsed time 0.052
# [MICE] Starting imputation round 66/110, elapsed time 0.052
# [MICE] Starting imputation round 67/110, elapsed time 0.056
# [MICE] Starting imputation round 68/110, elapsed time 0.056
# [MICE] Starting imputation round 69/110, elapsed time 0.056
# [MICE] Starting imputation round 70/110, elapsed time 0.056
# [MICE] Starting imputation round 71/110, elapsed time 0.056
# [MICE] Starting imputation round 72/110, elapsed time 0.056
# [MICE] Starting imputation round 73/110, elapsed time 0.060
# [MICE] Starting imputation round 74/110, elapsed time 0.060
# [MICE] Starting imputation round 75/110, elapsed time 0.060
# [MICE] Starting imputation round 76/110, elapsed time 0.060
# [MICE] Starting imputation round 77/110, elapsed time 0.060
# [MICE] Starting imputation round 78/110, elapsed time 0.064
# [MICE] Starting imputation round 79/110, elapsed time 0.064
# [MICE] Starting imputation round 80/110, elapsed time 0.064
# [MICE] Starting imputation round 81/110, elapsed time 0.064
# [MICE] Starting imputation round 82/110, elapsed time 0.064
# [MICE] Starting imputation round 83/110, elapsed time 0.064
# [MICE] Starting imputation round 84/110, elapsed time 0.068
# [MICE] Starting imputation round 85/110, elapsed time 0.068
# [MICE] Starting imputation round 86/110, elapsed time 0.068
# [MICE] Starting imputation round 87/110, elapsed time 0.068
# [MICE] Starting imputation round 88/110, elapsed time 0.068
# [MICE] Starting imputation round 89/110, elapsed time 0.068
# [MICE] Starting imputation round 90/110, elapsed time 0.072
# [MICE] Starting imputation round 91/110, elapsed time 0.072
# [MICE] Starting imputation round 92/110, elapsed time 0.072
# [MICE] Starting imputation round 93/110, elapsed time 0.072
# [MICE] Starting imputation round 94/110, elapsed time 0.072
# [MICE] Starting imputation round 95/110, elapsed time 0.076
# [MICE] Starting imputation round 96/110, elapsed time 0.076
# [MICE] Starting imputation round 97/110, elapsed time 0.076
# [MICE] Starting imputation round 98/110, elapsed time 0.076
# [MICE] Starting imputation round 99/110, elapsed time 0.076
# [MICE] Starting imputation round 100/110, elapsed time 0.076
# [MICE] Starting imputation round 101/110, elapsed time 0.080
# [MICE] Starting imputation round 102/110, elapsed time 0.080
# [MICE] Starting imputation round 103/110, elapsed time 0.080
# [MICE] Starting imputation round 104/110, elapsed time 0.080
# [MICE] Starting imputation round 105/110, elapsed time 0.080
# [MICE] Starting imputation round 106/110, elapsed time 0.080
# [MICE] Starting imputation round 107/110, elapsed time 0.084
# [MICE] Starting imputation round 108/110, elapsed time 0.084
# [MICE] Starting imputation round 109/110, elapsed time 0.084
# [MICE] Starting imputation round 110/110, elapsed time 0.084

# %%
plt.figure(figsize=[20,10])
sns.distplot(input_raw['Age'].dropna(axis=0), label='Original', kde=0)
sns.distplot(endog1['Age'], label='Imputed', kde=0)
plt.legend(fontsize=16)

# %%
exog1 = exog.reset_index()
endog2 = endog1.reset_index()
input_raw5 = po.concat([exog1, endog2], axis=1)
input_raw5['is_train'] = np.random.random(size=input_raw5.shape[0]) < 0.8

# %%
train = input_raw5[input_raw5['is_train']==True]
test = input_raw5[input_raw5['is_train']==False]

# %%
print(train.shape)
print(test.shape)
# Out:
# (733, 9)
# (158, 9)

# %%
#leia = GaussianNB()
leia = RandomForestClassifier(max_depth=2, random_state=0)
y_pred = leia.fit(train.drop('Survived', axis=1), train['Survived']).predict_proba(test.drop('Survived', axis=1))[:,1]
y_pred1 = leia.fit(train.drop('Survived', axis=1), train['Survived']).predict(test.drop('Survived', axis=1))

# %%
print("Number of mislabeled points out of a total %d points : %d" % (test.drop('Survived', axis=1).shape[0],(test['Survived'] != y_pred1).sum()))
# Out:
# Number of mislabeled points out of a total 158 points : 53

# %% [markdown]
# ## Confusion Matrix
#                     Actual 0        Actual 1
#     Predicted 0:    True Negative  | False Negative
# ______________________________
#     Predicted 1:    False Positive | True Positive

# %%
confusion_matrix(test['Survived'], y_pred1)
# Out:
# array([[97,  1],
#        [52,  8]])

# %% [markdown]
# ## ROC Curve

# %%
#fpr = dict()
#tpr = dict()
#roc_auc = dict()
#for i in range(2):
fpr, tpr, _ = roc_curve(test['Survived'], y_pred)
roc_auc = auc(fpr, tpr)

fpr1, tpr1, _ = roc_curve(test['Survived'], y_pred1)
roc_auc1 = auc(fpr1, tpr1)

# %%
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot(fpr1, tpr1, color='lime',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc1)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
